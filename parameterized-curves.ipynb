# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,6.28)
x = np.cos(t) 
y = np.sin(t)

# circle parameterized by one variable
plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.show()
